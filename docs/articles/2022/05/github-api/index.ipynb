# %% [markdown]
# ---
# title: GitHub API
# created: '2022-05-08T01:01:02-07:00'
# date: '2026-08-02T10:51:34-07:00'
# authors:
#   - bendu
# label: github-api
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - Python
#   - REST
#   - RESTful
#   - API
#   - GitHub
#   - gh
#   - ghapi
# ---

# %% [markdown]
# ## Shell Command - [gh](https://github.com/cli/cli)
# [gh](https://github.com/cli/cli)
# is GitHub's official command-line tool.
# Persoanlly,
# I'm not a fan of gh
# mainly because I'm not a fan of
# writing complicated (>10 lines) shell scripts.

# %% [markdown]
# ## Python Bindings - [ghapi](https://github.com/fastai/ghapi)
#
# 1. [ghapi](https://github.com/fastai/ghapi)
#     provides 100% always-updated coverage of the entire GitHub REST API
#     by automatically converting the OpenAPI spec to a Pythonic API.
#     ghapi is always up to date with the latest changes to GitHub APIs.
#
# 2. Last time I tried,
#     there seems to be issues in this Python library.

# %% [markdown]
# ## [github-rest-api](https://github.com/legendu-net/github_rest_api)
#
# [github-rest-api](https://github.com/legendu-net/github_rest_api)
# is a simpler Python wrapper over GitHub REST APIs
# with a focus on making GitHub Actions workflower eaiser using Python scripts.

# %% [markdown]
# ## Raw REST API
#
# It is very straightforward to call GitHub REST APIs.
# GitHub REST APIs Doc provides cURL, JavaScript and GitHub CLI examples.
# You can use [Convert cURL syntax to Python, Node.js, PHP, R](https://curl.trillworks.com/)
# or [curlconverter](https://github.com/NickCarneiro/curlconverter/)
# to convert cURL commands to Python requests code.
# Below are some examples of querying and manipulating GitHub repositories using REST APIs.
#
# - [List Repositories of an Organization](list-repositories-of-a-github-organization-using-rest-api)
#
# - [Delete a Repository Secret](delete-a-repository-secret-using-github-rest-api)
#
# - [](#manage-github-secrets-using-github-rest-api)
#
# - [Transfer a Repository](transfer-a-repository-using-github-rest-api)
#
# - [Querying Branches of GitHub Repositories Using Rest API](manipulate-branches-of-a-repository-using-github-rest-apis)
#
# - [Manipulate Pull Requests Using GitHub Rest APIs](manipulate-pull-requests-using-github-rest-apis)

# %% [markdown]
# ## References
#
# - [GitHub REST API Docs](https://docs.github.com/en/rest)
#
# - [GitHub REST API Tutorial - REST API Support In GitHub](https://www.softwaretestinghelp.com/github-rest-api-tutorial/)
#
# - [Hands on ghapi](hands-on-ghapi)
