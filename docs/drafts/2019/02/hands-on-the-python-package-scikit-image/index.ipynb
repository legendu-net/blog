# %% [markdown]
# ---
# title: Hands on the Python Package scikit-image
# created: '2019-02-16T00:00:00-08:00'
# date: '2026-08-11T22:19:32-07:00'
# authors:
#   - bendu
# label: hands-on-the-python-package-scikit-image
# license: CC-BY-4.0
# tags:
#   - programming
#   - Python
#   - Pillow
#   - computer vision
#   - CV
#   - image
#   - PIL
#   - similarity
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## References
#
# https://github.com/scikit-image/scikit-image
#
# https://scikit-image.org/
#
# https://scikit-image.org/docs/dev/api/skimage.measure.html
