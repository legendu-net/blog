// %% [markdown]
// ---
// title: Convert between Byte Array and String in Java
// created: '2019-11-27T00:00:00-08:00'
// date: '2026-08-11T22:19:32-07:00'
// authors:
//   - bendu
// label: convert-between-byte-array-and-string-in-java
// license: CC-BY-4.0
// tags:
//   - programming
//   - JVM
//   - Java
//   - byte array
//   - bytes
//   - string
// ---
//
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %% [markdown]
// [Convert byte[] array to String – Convert String to byte[] array in Java](https://howtodoinjava.com/array/convert-byte-array-string-vice-versa/)

// %%
import java.util.Arrays

// %% [markdown]
// ## String to Byte Array

// %%
byte[] bytes = "how are you".getBytes();
for(byte b : bytes){
    System.out.println(b);
}
// Out:
// 104
// 111
// 119
// 32
// 97
// 114
// 101
// 32
// 121
// 111
// 117
// null

// %% [markdown]
// ## Byte Array to String

// %%
byte[] bytes = "how are you".getBytes();
System.out.println(new String(bytes));
// Out:
// how are you
// null
