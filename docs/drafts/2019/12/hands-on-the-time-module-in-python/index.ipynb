# %% [markdown]
# ---
# title: Hands on the Time Module in Python
# created: '2019-12-23T00:00:00-08:00'
# date: '2026-08-11T22:19:32-07:00'
# authors:
#   - bendu
# label: hands-on-the-time-module-in-python
# license: CC-BY-4.0
# tags:
#   - programming
#   - Python
#   - time
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# The code below returns the execution time in seconds.

# %%
import time

start = time.time()
for i in range(1000):
    x = i * i
end = time.time()
print(end - start)
# Out:
# 0.0002493858337402344

# %% [markdown]
# ## References
#
# https://stackoverflow.com/questions/7370801/measure-time-elapsed-in-python
#
# https://docs.python.org/3/library/timeit.html
