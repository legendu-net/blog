// %% [markdown]
// ---
// title: Char in Rust
// created: '2020-04-08T00:00:00-07:00'
// date: '2026-06-12T22:15:55-07:00'
// authors:
//   - bendu
// label: char-in-rust
// license: CC-BY-4.0
// tags:
//   - programming
//   - Rust
//   - char
//   - character
// ---
//
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %%
:timing
:sccache 1

// %% [markdown]
// ## Character
//
// Rust supports unicode characters.
// Notice that emojis are single unicode characters.

// %%
let c1 = 'a';
c1
// Out:
// 'a'

// %%
let c2 = '\u{1f604}';
c2
// Out:
// '😄'

// %% [markdown]
// ## char::from_u32

// %%
'Z' as u32
// Out:
// 90

// %%
char::from_u32(90)
// Out:
// Some('Z')

// %%
let c = char::from_u32(0x2764);
c
// Out:
// Some('❤')

// %% [markdown]
// ## char::from_digit

// %%
char::from_digit(9, 10)
// Out:
// Some('9')

// %% [markdown]
// ## char::to_uppercase
//
// `char::to_uppercase` returns an interator instead of a char!

// %%
'a'.to_uppercase()
// Out:
// ToUppercase(One('A'))

// %%
'a'.to_uppercase().next()
// Out:
// Some('A')

// %%
'a'.to_uppercase().next().unwrap()
// Out:
// 'A'

// %% [markdown]
// ## References
//
// [Official Doc - char](https://doc.rust-lang.org/std/primitive.char.html)
//
// [String in Rust](string-in-rust)
