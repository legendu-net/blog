# %% [markdown]
# ---
# title: Tips on Google Spreadsheet
# created: '2020-04-23T22:42:29-07:00'
# date: '2026-06-12T22:15:55-07:00'
# authors:
#   - bendu
# label: tips-on-google-spreadsheet
# license: CC-BY-4.0
# tags:
#   - computer science
#   - Google
#   - spreadsheet
#   - pivot table
#   - pivot
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## Pivot Table
#
# [Create & use pivot tables](https://support.google.com/docs/answer/1272900?co=GENIE.Platform%3DDesktop&hl=en)

# %% [markdown]
# ## References
#
# [Use Python With Google Spreadsheet](use-python-with-google-spreadsheet)
#
# [Pivot Table in SQL](pivot-table-in-sql)
