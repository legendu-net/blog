# %% [markdown]
# ---
# title: Query pandas Data Frames Using SQL
# created: '2020-06-27T12:26:43-07:00'
# date: '2026-08-11T22:19:32-07:00'
# authors:
#   - bendu
# label: query-pandas-data-frames-using-sql
# license: CC-BY-4.0
# tags:
#   - computer science
#   - pandas
#   - DataFrame
#   - Dask
#   - SQL
#   - query
#   - database
#   - framequery
#   - pandasql
#   - ibis
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## [framequery](https://github.com/chmp/framequery)

# %% [markdown]
# ## [pandasql](https://github.com/yhat/pandasql)

# %% [markdown]
# ## [ibis](https://github.com/ibis-project/ibis)

# %% [markdown]
# ## References
#
# https://github.com/chmp/framequery
#
# https://github.com/chmp/framequery/blob/master/docs/Usage.md
#
# https://github.com/chmp/framequery/blob/master/docs/API.md
