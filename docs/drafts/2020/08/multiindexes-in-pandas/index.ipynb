# %% [markdown]
# ---
# title: MultiIndexes in pandas
# created: '2020-08-10T11:01:40-07:00'
# date: '2026-06-12T22:31:51-07:00'
# authors:
#   - bendu
# label: multiindexes-in-pandas
# license: CC-BY-4.0
# tags:
#   - programming
#   - Python
#   - pandas
#   - index
#   - DataFrame
#   - MultiIndex
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## Multi-Index

# %%
pd.MultiIndex.from_product([[jj.index.name], jj.index.values])

# %% [markdown]
# ## Get Levels

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html

# %%
get_level_values

# %%
it seems to me that there are even easier ways sometimes ...

# %% [markdown]
# Extract columns whose 2nd-level index is `bi` from the data frame `df`.

# %%
df.loc(axis=1)[:, "bi"]

# %% [markdown]
# ## References
#
# https://www.youtube.com/watch?v=tcRGa2soc-c
#
# https://pandas.pydata.org/pandas-docs/stable/advanced.html
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.05-hierarchical-indexing.html
#
# [Add level to a MultiIndexes in pandas](add-level-to-a-multiindexes-in-pandas)
#
# [Construct MultiIndexes in pandas](construct-multiindexes-in-pandas)
#
# [Understand Index in pandas](understand-index-in-pandas)
