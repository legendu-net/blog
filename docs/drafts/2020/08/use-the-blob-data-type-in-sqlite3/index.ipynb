# %% [markdown]
# ---
# title: Use the Blob Data Type in SQLite3
# created: '2020-08-07T17:33:00-07:00'
# date: '2026-08-11T22:19:32-07:00'
# authors:
#   - bendu
# label: use-the-blob-data-type-in-sqlite3
# license: CC-BY-4.0
# tags:
#   - computer science
#   - SQLite3
#   - SQL
#   - data type
#   - Blob
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
import io
import datetime
import sqlite3
import pandas as pd

# %%
df = pd.DataFrame({"x": [1, 2, 3, 4, 5], "y": [5, 4, 3, 2, 1], "z": [1, 1, 1, 1, 1]})

df.head()
# Out:
#    x  y  z
# 0  1  5  1
# 1  2  4  1
# 2  3  3  1
# 3  4  2  1
# 4  5  1  1

# %%
bio = io.BytesIO()
df.to_parquet(bio)
bio.seek(0)
# Out:
# 0

# %%
conn = sqlite3.connect("blob.sqlite3")
conn.execute(
    """
    CREATE TABLE IF NOT EXISTS queries (
        query Text NOT NULL PRIMARY KEY,
        timestamp Real NOT NULL,
        data Blob NOT NULL
    )
    """
)
conn.execute(
    """
    insert into queries (
        query, timestamp, data
    ) values (
        ?, ?, ?
    )
    """,
    ["select * from queries", datetime.datetime.now().timestamp(), bio.read()],
)

# %%
rows = conn.execute("select * from queries").fetchall()

# %%
bio2 = io.BytesIO(rows[0][2])

# %%
bio2.seek(0)
# Out:
# 0

# %%
pd.read_parquet(bio2)
# Out:
#    x  y  z
# 0  1  5  1
# 1  2  4  1
# 2  3  3  1
# 3  4  2  1
# 4  5  1  1
