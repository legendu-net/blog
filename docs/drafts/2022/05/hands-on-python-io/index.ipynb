# %% [markdown]
# ---
# title: Hands on Python IO
# created: '2022-05-01T11:57:02-07:00'
# date: '2026-06-12T22:15:55-07:00'
# authors:
#   - bendu
# label: hands-on-python-io
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - Python
#   - IO
#   - BytesIO
#   - StringIO
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## StringIO

# %%
from io import StringIO

# %%
sio = StringIO("")
sio

# %%
sio.write("hello world")
# Out:
# 11

# %%
sio.getvalue()
# Out:
# 'hello world'

# %% [markdown]
# ## BytesIO
#
# 1. You can write anything into a BytesIO.
#     For example,
#     you can pass a BytesIO to `pandas.DataFrame.to_parquet`
#     to write a pandas DataFrame to the BytesIO in the Parquet format.
#     For more details,
#     please refer to [Pandas IO](pandas-io).

# %%
from io import BytesIO

# %%
bio = BytesIO()
bio

# %%
bio.write(b"hello world")
bio

# %%
bio.getvalue()
# Out:
# b'hello world'

# %% [markdown]
# ## References
#
# [io — Core tools for working with streams](https://docs.python.org/3/library/io.html)
