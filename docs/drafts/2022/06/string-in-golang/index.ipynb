// %% [markdown]
// ---
// title: String in Golang
// created: '2022-06-09T22:17:07-07:00'
// date: '2026-06-12T22:15:55-07:00'
// authors:
//   - bendu
// label: string-in-golang
// license: CC-BY-4.0
// tags:
//   - computer science
//   - programming
//   - golang
//   - string
//   - str
//   - multiline
// ---
//
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %% [markdown]
// ## Tips and Traps
//
// 1. In Golang,
//    a string is implemented as a struct
//    containing a data pointer (pointing to a read-only slice of bytes)
//    and a length.
//
// 2. Raw string literals,
//     delimited by backticks (back quotes),
//     are interpreted literally.
//     They can contain line breaks,
//     and backslashes have no special meaning.
//
// 3. The built-in function `len` returns the length of bytes of a string.
//     It is not necessary the length of unicode characters.
//     For example,
//     calling `len` on a Chinese character returns 3 instead of 1.

// %%
import "strings"
import "fmt"
import "strconv"
import "reflect"

// %% [markdown]
// ## Backtick / Multi-line Strings

// %%
s := `this is
a multiline
    string`
s
// Out:
// this is
// a multiline
//     string

// %% [markdown]
// ## Slicing of Strings

// %%
s := "how are you"
s
// Out:
// how are you

// %% [markdown]
// Each element of a string is a unsigned 8-bit integer
// (since Golang uses the UTF-8 encoding for strings).
// Notice it might or might not correspond to a character in the original string
// since an UTF-8 character might use up to 4 bytes.

// %%
s[0]
// Out:
// 104

// %%
reflect.TypeOf(s[0])
// Out:
// uint8

// %%
s[:]
// Out:
// how are you

// %%
s[2:]
// Out:
// w are you

// %%
s[2:6]
// Out:
// w ar

// %%
strconv.Itoa(2)
// Out:
// 2

// %%
strconv.Atoi("20")
// Out:
// 20 <nil>

// %% [markdown]
// ## Concatenate Strings

// %%
"how " + "are"
// Out:
// how are

// %%
"how " + 2
// Out:
// how how

// %%
"how " * 2
// Out:
// invalid binary operation "how " * 2

// %%
"how " + strconv.Itoa(2)
// Out:
// how 2

// %% [markdown]
// ## Concatenate/Join an Array of Strings
//
// Please refer to
// [Manipulate Strings Using the `strings` Module in Golang](manipulate-strings-using-the-strings-module-in-golang-strings-join)
// for more discussions.

// %% [markdown]
// ## Comparing Strings

// %% [markdown]
// ## Convert Integers to Strings

// %%
import "fmt"
import "strconv"

// %%
fmt.Sprintf("%d", 1)
// Out:
// 1

// %%
strconv.Itoa(1)
// Out:
// 1

// %% [markdown]
// ## Convert Strings to Integers

// %%
i, err := strconv.ParseInt("1", 10, 64)
i
// Out:
// 1

// %% [markdown]
// ## The `strings` Module
//
// Please refer to
// [Manipulate Strings Using the `strings` Module in Golang](manipulate-strings-using-the-strings-module-in-golang)
// for detailed discussions.

// %% [markdown]
// ## Format Strings
//
// Please refer to
// [Format Strings in Golang](format-strings-in-golang)
// for detailed discussions.

// %% [markdown]
// ## Strings in Golang Are UTF-8
//
// Please refer to
// [Strings in Golang Are UTF-8](strings-in-golang-are-utf-8)
// for detailed discussions.

// %% [markdown]
// ## References
//
// - [fmt.Sprintf](https://pkg.go.dev/fmt#Sprintf)
//
// - [Golang Standard package - strings](https://pkg.go.dev/strings)
//
// - [Golang Standard Package - strconv](https://pkg.go.dev/strconv)
//
// - [Format Strings in Golang](format-strings-in-golang)
//
// - [Strings in Golang Are UTF-8](strings-in-golang-are-utf-8)
//
// - [Manipulate Strings Using the `strings` Module in Golang](manipulate-strings-using-the-strings-module-in-golang)
//
// - [How to Use Strings in Go (Golang)](https://www.developer.com/languages/strings-in-go/)
