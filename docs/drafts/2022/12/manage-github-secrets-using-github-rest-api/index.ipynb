# %% [markdown]
# ---
# title: Manage GitHub Secrets Using GitHub REST API
# created: '2022-12-17T13:43:34-08:00'
# date: '2026-06-20T17:58:22-07:00'
# authors:
#   - bendu
# label: manage-github-secrets-using-github-rest-api
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - GitHub
#   - REST
#   - RESTful
#   - API
#   - delete
#   - Actions
#   - secrets
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
import getpass
import os
import subprocess
from requests.exceptions import HTTPError
from github_rest_api import Organization, Repository, RepositoryType, User

# %%
env = os.environ.copy()
env["GOPASS_AGE_PASSWORD"] = getpass.getpass("Enter gopass password: ")
token = subprocess.run(
    ["gopass", "show", "-o", "github.com/token"],
    check=True,
    capture_output=True,
    text=True,
    env=env,
).stdout

# %% [markdown]
# ## List Secrets in a Repository

# %%
repo = Repository(token=token, repo="legendu-net/poker-rs")
repo

# %%
repo.get_secrets()
# Out:
# [{'name': 'GITHUBACTIONS',
#   'created_at': '2026-06-20T17:35:49Z',
#   'updated_at': '2026-06-20T17:35:49Z'}]

# %% [markdown]
# ## List Secrets in a Organization

# %%
org = Organization(token=token, org="legendu-net")
org

# %%
org.get_secrets()
# Out:
# [{'name': 'DOCKER_BASE_DISPATCH',
#   'created_at': '2026-01-08T18:56:08Z',
#   'updated_at': '2026-01-08T19:01:57Z',
#   'visibility': 'selected',
#   'selected_repositories_url': 'https://api.github.com/orgs/legendu-net/actions/secrets/DOCKER_BASE_DISPATCH/repositories'},
#  {'name': 'GITHUBACTIONS',
#   'created_at': '2022-05-03T20:39:04Z',
#   'updated_at': '2026-06-20T17:34:54Z',
#   'visibility': 'all'},
#  {'name': 'PYPI_GITHUB_REST_API',
#   'created_at': '2026-01-02T01:23:21Z',
#   'updated_at': '2026-01-02T01:23:21Z',
#   'visibility': 'all'},
#  {'name': 'PYPI_TOKEN',
#   'created_at': '2026-01-02T01:30:11Z',
#   'updated_at': '2026-01-02T01:30:11Z',
#   'visibility': 'all'}]

# %% [markdown]
# ## Add/Update a Secret

# %%
repo = Repository(token=token, repo="dclong/test")

# %%
repo.get_secrets()
# Out:
# []

# %%
public_key = repo.get_secret_public_key()

# %%
repo.create_or_update_secret(
    name="MY_TOKEN",
    value="this is a fake token",
    public_key=public_key,
)
# Out:
# <Response [201]>

# %%
repo.get_secrets()
# Out:
# [{'name': 'MY_TOKEN',
#   'created_at': '2026-06-21T00:48:19Z',
#   'updated_at': '2026-06-21T00:48:19Z'}]

# %% [markdown]
# ## Delete a Secret

# %%
repo.delete_secret("MY_TOKEN")
# Out:
# <Response [204]>

# %%
repo.get_secrets()
# Out:
# []
