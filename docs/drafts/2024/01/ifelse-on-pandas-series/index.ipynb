# %% [markdown]
# ---
# title: ifelse on pandas Series
# created: '2024-01-16T07:45:58-08:00'
# date: '2026-08-11T22:19:32-07:00'
# authors:
#   - bendu
# label: ifelse-on-pandas-series
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - pandas
#   - series
#   - if
#   - ifelse
#   - numpy
#   - where
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## Series.apply + Lambda Function

# %% [markdown]
# ## DataFrame.apply + Lambda Function
#
# axis=1: apply the lambda function on each row

# %% [markdown]
# ## List Comprehension

# %% [markdown]
# ## [numpy.where](https://numpy.org/doc/stable/reference/generated/numpy.where.html)
# [numpy.where](https://numpy.org/doc/stable/reference/generated/numpy.where.html)
# is vectorized ifelse.
