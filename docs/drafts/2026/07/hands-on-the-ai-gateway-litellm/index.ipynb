# %% [markdown]
# ---
# title: Hands on the AI Gateway Litellm
# created: '2026-07-18T15:25:50.458933-07:00'
# date: '2026-07-18T15:25:50.458941-07:00'
# authors:
#   - bendu
# label: hands-on-the-ai-gateway-litellm
# license: CC-BY-4.0
# tags:
#   - programming
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
import litellm

# %%
response = litellm.get_supported_openai_params(model="deepseek/deepseek-chat")
response

# %%
response = litellm.get_supported_openai_params(model="moonshot/kimi-k2.5")
response
