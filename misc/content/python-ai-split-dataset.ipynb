# %% [markdown]
# - Title: Split a Dataset into Train and Test Datasets in Python
# - Slug: python-ai-split-dataset
# - Date: 2020-02-04 14:43:46
# - Category: Programming
# - Tags: programming, Python, AI, data science, machine learning
# - Author: Ben Du

# %% [markdown]
# [sklearn.model_selection.train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
# is the best way to split a dataset into train and test subset.
# It supports both pandas DataFrames/Series and numpy arrays.

# %%
import pandas as pd

# %%
df = pd.read_csv("http://www.legendu.net/media/data/iris.csv")
df.head()
# Out:
#    id  sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0   1              5.1             3.5              1.4             0.2
# 1   2              4.9             3.0              1.4             0.2
# 2   3              4.7             3.2              1.3             0.2
# 3   4              4.6             3.1              1.5             0.2
# 4   5              5.0             3.6              1.4             0.2
#
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.2, random_state=119)

# %% [markdown]
# Notice that an integer value 119 is passed to the parameter `random_state`.
# This is STRONGLY suggested as it enables to reproduce your work later.
# It is generally a good idea to set a seed for the random number generator
# when you build a model.

# %%
train.head()
# Out:
#       id  sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 122  123              7.7             2.8              6.7             2.0
# 109  110              7.2             3.6              6.1             2.5
# 34    35              4.9             3.1              1.5             0.1
# 123  124              6.3             2.7              4.9             1.8
# 69    70              5.6             2.5              3.9             1.1
#
#              species
# 122   Iris-virginica
# 109   Iris-virginica
# 34       Iris-setosa
# 123   Iris-virginica
# 69   Iris-versicolor

# %%
train.shape
# Out:
# (120, 6)

# %%
test.head()
# Out:
#       id  sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 37    38              4.9             3.1              1.5             0.1
# 63    64              6.1             2.9              4.7             1.4
# 31    32              5.4             3.4              1.5             0.4
# 102  103              7.1             3.0              5.9             2.1
# 126  127              6.2             2.8              4.8             1.8
#
#              species
# 37       Iris-setosa
# 63   Iris-versicolor
# 31       Iris-setosa
# 102   Iris-virginica
# 126   Iris-virginica

# %%
test.shape
# Out:
# (30, 6)

# %% [markdown]
# ## References

# %% [markdown]
# https://stackoverflow.com/questions/24147278/how-do-i-create-test-and-train-samples-from-one-dataframe-with-pandas
